# %%
import csv
import pandas as pd
import numpy as np
data = pd.read_csv('tableau_cleaned.csv')

# %%
data
# Out:
#      country  year      value
# 0     Angola  2009    0.00000
# 1     Angola  2009    0.00000
# 2     Angola  2009    0.00000
# 3     Angola  2009    0.00000
# 4     Angola  2010    0.00000
# 5     Angola  2010    0.00000
# 6     Angola  2010    0.00000
# 7     Angola  2010    0.00000
# 8     Angola  2011    0.00000
# 9     Angola  2011    0.00000
# 10    Angola  2011    0.00000
# 11    Angola  2011    0.00000
# 12    Angola  2012  118.00000
# 13    Angola  2012    0.00000
# 14    Angola  2012    0.00000
# 15    Angola  2012    0.00000
# 16    Angola  2013    0.00000
# 17    Angola  2013    0.00000
# 18    Angola  2013    0.00000
# 19    Angola  2013    0.00000
# 20    Angola  2014    0.00000
# 21    Angola  2014    0.00000
# 22    Angola  2014    0.00000
# 23    Angola  2014    0.00000
# 24    Angola  2015    0.00000
# 25    Angola  2015    0.00000
# 26    Angola  2015    0.00000
# 27    Angola  2015    0.00000
# 28    Angola  2016    0.00000
# 29    Angola  2016    0.00000
# ...

# %%
data['value'] = data['value'].astype('int64')

# %%
data_clean = data.groupby(['country', 'year'], as_index=False).sum()

# %%
data_clean
# Out:
#        country  year    value
# 0       Angola  2009        0
# 1       Angola  2010        0
# 2       Angola  2011        0
# 3       Angola  2012      118
# 4       Angola  2013        0
# 5       Angola  2014        0
# 6       Angola  2015        0
# 7       Angola  2016        0
# 8       Angola  2017        0
# 9    Australia  2009       26
# 10   Australia  2010       60
# 11   Australia  2011       34
# 12   Australia  2012      119
# 13   Australia  2013        5
# 14   Australia  2014        0
# 15   Australia  2015        0
# 16   Australia  2016        0
# 17   Australia  2017        0
# 18      Belize  2009        0
# 19      Belize  2010       89
# 20      Belize  2011     1787
# 21      Belize  2012     4991
# 22      Belize  2013     5375
# 23      Belize  2014     3892
# 24      Belize  2015      669
# 25      Belize  2016      392
# 26      Belize  2017        0
# 27       Benin  2009      282
# 28       Benin  2010     3301
# 29       Benin  2011    40805
# ...

# %%
data_clean.to_csv('result.csv', sep=',', encoding='utf-8')
